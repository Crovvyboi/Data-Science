# %%
import numpy as np
import pandas as pd

ytmpv = pd.read_csv('Youtube most popular videos US.csv', sep=',')

# %%
ytmpv.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
avgviews = ytmpv["views"].mean()
stdLength = 1

series = pd.Series( np.random.normal(avgviews, stdLength, 5000) )

# %%
series.plot(kind='hist', bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
avglikes = ytmpv["likes"].mean()
stdLength = 1

series = pd.Series( np.random.normal(avgviews, stdLength, 5000) )

# %%
series.plot(kind='hist', bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# De piek zit in het midden, rond het gemiddelde
# Beiden zien eruit als een normaalverdeling
